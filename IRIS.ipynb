# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('species',axis =1 )
y = df['species']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model_knn = KNeighborsClassifier(n_neighbors=13)

# %%
model_knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=13)

# %%
model_knn.score(X_test,y_test)
# Out:
# 1.0

# %%
# 100% accuracy means its an overfit when n_neighbout = 13

# %%
from sklearn.svm import SVC

# %%
model_svm = SVC(gamma='auto')

# %%
model_svm.fit(X_train, y_train)
# Out:
# SVC(gamma='auto')

# %%
model_svm.score(X_test,y_test)                   # by changing the hyper parameters we may get various accuracies
# Out:
# 1.0

# %% [markdown]
# # now lets use the grid search cv

# %%
from sklearn.model_selection import GridSearchCV

# %%
classifier = GridSearchCV((model_svm),{
    'C' : [1,10,20,30],
    'kernel' : ['rbf','linear'],
 }, cv = 5, return_train_score=False)

# %%
classifier.fit(X,y)            # we don't reeally have to train & test our data in GridSearchCV
# Out:
# GridSearchCV(cv=5, estimator=SVC(gamma='auto'),
#              param_grid={'C': [1, 10, 20, 30], 'kernel': ['rbf', 'linear']})

# %%
classifier.cv_results_
# Out:
# {'mean_fit_time': array([0.00188327, 0.00182428, 0.00153594, 0.0013586 , 0.00141983,
#         0.00139976, 0.0013998 , 0.00133085]),
#  'std_fit_time': array([2.97673593e-04, 4.76301049e-04, 9.15294359e-05, 3.38888675e-05,
#         3.76533519e-05, 2.81354128e-05, 2.62946186e-05, 1.20187560e-05]),
#  'mean_score_time': array([0.00137491, 0.0023417 , 0.00121331, 0.00105782, 0.00109911,
#         0.00105486, 0.00107055, 0.00102286]),
#  'std_score_time': array([1.78832587e-04, 1.83044945e-03, 7.75531332e-05, 4.68807321e-05,
#         4.75822800e-05, 2.47939733e-05, 1.90206033e-05, 1.25792860e-05]),
#  'param_C': masked_array(data=[1, 1, 10, 10, 20, 20, 30, 30],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value=999999),
#  'param_kernel': masked_array(data=['rbf', 'linear', 'rbf', 'linear', 'rbf', 'linear',
#                     'rbf', 'linear'],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value=np.str_('?'),
#              dtype=object),
#  'params': [{'C': 1, 'kernel': 'rbf'},
#   {'C': 1, 'kernel': 'linear'},
#   {'C': 10, 'kernel': 'rbf'},
#   {'C': 10, 'kernel': 'linear'},
#   {'C': 20, 'kernel': 'rbf'},
#   {'C': 20, 'kernel': 'linear'},
#   {'C': 30, 'kernel': 'rbf'},
#   {'C': 30, 'kernel': 'linear'}],
#  'split0_test_score': array([0.96666667, 0.96666667, 0.96666667, 1.        , 0.96666667,
#         1.        , 0.96666667, 1.        ]),
#  'split1_test_score': array([1., 1., 1., 1., 1., 1., 1., 1.]),
#  'split2_test_score': array([0.96666667, 0.96666667, 0.96666667, 0.9       , 0.9       ,
#         0.9       , 0.9       , 0.9       ]),
#  'split3_test_score': array([0.96666667, 0.96666667, 0.96666667, 0.96666667, 0.96666667,
#         0.93333333, 0.93333333, 0.9       ]),
#  'split4_test_score': array([1., 1., 1., 1., 1., 1., 1., 1.]),
#  'mean_test_score': array([0.98      , 0.98      , 0.98      , 0.97333333, 0.96666667,
#         0.96666667, 0.96      , 0.96      ]),
#  'std_test_score': array([0.01632993, 0.01632993, 0.01632993, 0.03887301, 0.03651484,
#         0.0421637 , 0.03887301, 0.04898979]),
#  'rank_test_score': array([1, 1, 1, 4, 5, 6, 7, 7], dtype=int32)}

# %%
results = pd.DataFrame(classifier.cv_results_)

# %%
results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0       0.001883      0.000298         0.001375        0.000179        1
# 1       0.001824      0.000476         0.002342        0.001830        1
# 2       0.001536      0.000092         0.001213        0.000078       10
# 3       0.001359      0.000034         0.001058        0.000047       10
# 4       0.001420      0.000038         0.001099        0.000048       20
# 5       0.001400      0.000028         0.001055        0.000025       20
# 6       0.001400      0.000026         0.001071        0.000019       30
# 7       0.001331      0.000012         0.001023        0.000013       30
#
#   param_kernel                         params  split0_test_score  \
# 0          rbf      {'C': 1, 'kernel': 'rbf'}           0.966667
# 1       linear   {'C': 1, 'kernel': 'linear'}           0.966667
# 2          rbf     {'C': 10, 'kernel': 'rbf'}           0.966667
# 3       linear  {'C': 10, 'kernel': 'linear'}           1.000000
# 4          rbf     {'C': 20, 'kernel': 'rbf'}           0.966667
# 5       linear  {'C': 20, 'kernel': 'linear'}           1.000000
# 6          rbf     {'C': 30, 'kernel': 'rbf'}           0.966667
# 7       linear  {'C': 30, 'kernel': 'linear'}           1.000000
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0                1.0           0.966667           0.966667                1.0
# 1                1.0           0.966667           0.966667                1.0
# 2                1.0           0.966667           0.966667                1.0
# 3                1.0           0.900000           0.966667                1.0
# 4                1.0           0.900000           0.966667                1.0
# 5                1.0           0.900000           0.933333                1.0
# 6                1.0           0.900000           0.933333                1.0
# 7                1.0           0.900000           0.900000                1.0
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.980000        0.016330                1
# 1         0.980000        0.016330                1
# 2         0.980000        0.016330                1
# 3         0.973333        0.038873                4
# 4         0.966667        0.036515                5
# 5         0.966667        0.042164                6
# 6         0.960000        0.038873                7
# 7         0.960000        0.048990                7

# %%
results[['param_C','param_kernel','mean_test_score']]
# Out:
#    param_C param_kernel  mean_test_score
# 0        1          rbf         0.980000
# 1        1       linear         0.980000
# 2       10          rbf         0.980000
# 3       10       linear         0.973333
# 4       20          rbf         0.966667
# 5       20       linear         0.966667
# 6       30          rbf         0.960000
# 7       30       linear         0.960000

# %%
# now with knn model

# %%
classifier2 = GridSearchCV((model_knn),{
    'n_neighbors' : [3,5,7,9,11,13]
 }, cv = 5, return_train_score=False)

# %%
classifier2.fit(X,y)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(n_neighbors=13),
#              param_grid={'n_neighbors': [3, 5, 7, 9, 11, 13]})

# %%
classifier2.cv_results_
# Out:
# {'mean_fit_time': array([0.00289569, 0.00144029, 0.00128441, 0.00144072, 0.00131788,
#         0.00129981]),
#  'std_fit_time': array([1.52189486e-03, 1.32034392e-04, 2.59188082e-05, 2.42477785e-04,
#         5.12921654e-05, 5.14843710e-05]),
#  'mean_score_time': array([0.00567641, 0.00270815, 0.00246572, 0.00278797, 0.00272107,
#         0.002777  ]),
#  'std_score_time': array([3.42746621e-03, 2.59069205e-04, 4.62195185e-05, 5.85948524e-04,
#         2.51044552e-04, 5.95833905e-04]),
#  'param_n_neighbors': masked_array(data=[3, 5, 7, 9, 11, 13],
#               mask=[False, False, False, False, False, False],
#         fill_value=999999),
#  'params': [{'n_neighbors': 3},
#   {'n_neighbors': 5},
#   {'n_neighbors': 7},
#   {'n_neighbors': 9},
#   {'n_neighbors': 11},
#   {'n_neighbors': 13}],
#  'split0_test_score': array([0.96666667, 0.96666667, 0.96666667, 0.96666667, 0.93333333,
#         0.93333333]),
#  'split1_test_score': array([0.96666667, 1.        , 1.        , 1.        , 1.        ,
#         1.        ]),
#  'split2_test_score': array([0.93333333, 0.93333333, 0.96666667, 0.96666667, 1.        ,
#         0.96666667]),
#  'split3_test_score': array([0.96666667, 0.96666667, 0.96666667, 0.93333333, 0.96666667,
#         0.96666667]),
#  'split4_test_score': array([1., 1., 1., 1., 1., 1.]),
#  'mean_test_score': array([0.96666667, 0.97333333, 0.98      , 0.97333333, 0.98      ,
#         0.97333333]),
#  'std_test_score': array([0.02108185, 0.02494438, 0.01632993, 0.02494438, 0.02666667,
#         0.02494438]),
#  'rank_test_score': array([6, 3, 1, 3, 1, 3], dtype=int32)}

# %%
results2 = pd.DataFrame(classifier2.cv_results_)

# %%
results2
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.002896      0.001522         0.005676        0.003427
# 1       0.001440      0.000132         0.002708        0.000259
# 2       0.001284      0.000026         0.002466        0.000046
# 3       0.001441      0.000242         0.002788        0.000586
# 4       0.001318      0.000051         0.002721        0.000251
# 5       0.001300      0.000051         0.002777        0.000596
#
#    param_n_neighbors               params  split0_test_score  \
# 0                  3   {'n_neighbors': 3}           0.966667
# 1                  5   {'n_neighbors': 5}           0.966667
# 2                  7   {'n_neighbors': 7}           0.966667
# 3                  9   {'n_neighbors': 9}           0.966667
# 4                 11  {'n_neighbors': 11}           0.933333
# 5                 13  {'n_neighbors': 13}           0.933333
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.966667           0.933333           0.966667                1.0
# 1           1.000000           0.933333           0.966667                1.0
# 2           1.000000           0.966667           0.966667                1.0
# 3           1.000000           0.966667           0.933333                1.0
# 4           1.000000           1.000000           0.966667                1.0
# 5           1.000000           0.966667           0.966667                1.0
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.966667        0.021082                6
# 1         0.973333        0.024944                3
# 2         0.980000        0.016330                1
# 3         0.973333        0.024944                3
# 4         0.980000        0.026667                1
# 5         0.973333        0.024944                3

# %% [markdown]
# # Random Search CV

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
classifier3 = RandomizedSearchCV((model_svm),{
    'C' : [1,10,20,30],
    'kernel' : ['rbf','linear']
},n_iter=4, cv = 5,return_train_score = False)

# %%
classifier3.fit(X_train,y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=SVC(gamma='auto'), n_iter=4,
#                    param_distributions={'C': [1, 10, 20, 30],
#                                         'kernel': ['rbf', 'linear']})

# %%
classifier3.cv_results_
# Out:
# {'mean_fit_time': array([0.00192118, 0.00275879, 0.00468416, 0.00387173]),
#  'std_fit_time': array([0.00052787, 0.00152517, 0.00027967, 0.00015733]),
#  'mean_score_time': array([0.00147181, 0.00221181, 0.00347447, 0.00308104]),
#  'std_score_time': array([0.0004175 , 0.00121187, 0.0002597 , 0.00016939]),
#  'param_kernel': masked_array(data=['rbf', 'linear', 'linear', 'linear'],
#               mask=[False, False, False, False],
#         fill_value=np.str_('?'),
#              dtype=object),
#  'param_C': masked_array(data=[10, 30, 20, 1],
#               mask=[False, False, False, False],
#         fill_value=999999),
#  'params': [{'kernel': 'rbf', 'C': 10},
#   {'kernel': 'linear', 'C': 30},
#   {'kernel': 'linear', 'C': 20},
#   {'kernel': 'linear', 'C': 1}],
#  'split0_test_score': array([0.95, 0.95, 0.95, 1.  ]),
#  'split1_test_score': array([0.8 , 0.85, 0.85, 0.9 ]),
#  'split2_test_score': array([0.9, 0.9, 0.9, 0.9]),
#  'split3_test_score': array([1.  , 1.  , 0.95, 1.  ]),
#  'split4_test_score': array([1.  , 1.  , 1.  , 0.95]),
#  'mean_test_score': array([0.93, 0.94, 0.93, 0.95]),
#  'std_test_score': array([0.07483315, 0.05830952, 0.0509902 , 0.04472136]),
#  'rank_test_score': array([3, 2, 4, 1], dtype=int32)}

# %%
results3 = pd.DataFrame(classifier3.cv_results_)

# %%
results3
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_kernel  \
# 0       0.001921      0.000528         0.001472        0.000417          rbf
# 1       0.002759      0.001525         0.002212        0.001212       linear
# 2       0.004684      0.000280         0.003474        0.000260       linear
# 3       0.003872      0.000157         0.003081        0.000169       linear
#
#    param_C                         params  split0_test_score  \
# 0       10     {'kernel': 'rbf', 'C': 10}               0.95
# 1       30  {'kernel': 'linear', 'C': 30}               0.95
# 2       20  {'kernel': 'linear', 'C': 20}               0.95
# 3        1   {'kernel': 'linear', 'C': 1}               1.00
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0               0.80                0.9               1.00               1.00
# 1               0.85                0.9               1.00               1.00
# 2               0.85                0.9               0.95               1.00
# 3               0.90                0.9               1.00               0.95
#
#    mean_test_score  std_test_score  rank_test_score
# 0             0.93        0.074833                3
# 1             0.94        0.058310                2
# 2             0.93        0.050990                4
# 3             0.95        0.044721                1

# %%
results3[['param_C','param_kernel','mean_test_score']]
# Out:
#    param_C param_kernel  mean_test_score
# 0       10          rbf             0.93
# 1       30       linear             0.94
# 2       20       linear             0.93
# 3        1       linear             0.95
